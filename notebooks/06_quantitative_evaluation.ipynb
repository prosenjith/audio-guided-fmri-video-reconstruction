# %% [markdown]
# # 06 – Quantitative Evaluation
#
# This notebook evaluates reconstructed videos using:
# SSIM, PSNR, and LPIPS.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/prosenjith/audio-guided-fmri-video-reconstruction.git
# %cd audio-guided-fmri-video-reconstruction
# !pip install -r requirements.txt

# %%
# !python scripts/evaluate_video_reconstruction.py --config configs/video_evaluation.yaml
