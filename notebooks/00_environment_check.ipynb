# %% [markdown]
# # 00 – Environment Check
#
# This notebook verifies that the execution environment is correctly set up.
# It checks:
# - Google Drive mounting
# - Repository cloning
# - Dependency installation
# - CUDA availability

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/prosenjith/audio-guided-fmri-video-reconstruction.git
# %cd audio-guided-fmri-video-reconstruction
# !pip install -r requirements.txt

# %%
import torch, yaml, nibabel, numpy as np
print("Environment OK")
print("CUDA available:", torch.cuda.is_available())
