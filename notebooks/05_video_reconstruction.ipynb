# %% [markdown]
# # 05 – Video Reconstruction
#
# This notebook reconstructs videos conditioned on predicted motion latents.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/prosenjith/audio-guided-fmri-video-reconstruction.git
# %cd audio-guided-fmri-video-reconstruction
# !pip install -r requirements.txt

# %%
# !python scripts/generate_videos.py --config configs/video_reconstruction.yaml
