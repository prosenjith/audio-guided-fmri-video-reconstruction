# %% [markdown]
# # Debug fMRI Embedding Pipeline
#
# This notebook only runs the pipeline script.
# All logic lives in `src/` and `scripts/`.

# %%
# !python ../scripts/run_fmri_embeddings.py
# Out:
# ...
# Running fMRI Embedding Pipeline
# FMRI_ROOT : /content/drive/MyDrive/Research/data/fMRI/fMRI_extracted
# OUT_ROOT  : /content/drive/MyDrive/Research/data/fMRI/fMRI_embeddings_new
# ...
#
# Traceback (most recent call last):
#   File "/Users/prosenjithroyshuvo/Desktop/Research/Thesis/Main Thesis/Code/audio-guided-fmri-video-reconstruction/notebooks/../scripts/run_fmri_embeddings.py", line 43, in <module>
#     for subject in sorted(os.listdir(FMRI_ROOT)):
#                           ^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Research/data/fMRI/fMRI_extracted'
