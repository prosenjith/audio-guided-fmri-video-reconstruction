# %% [markdown]
# # 07 – Qualitative Evaluation
#
# This notebook launches an interactive annotation UI
# for human evaluation of reconstructed videos.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/prosenjith/audio-guided-fmri-video-reconstruction.git
# %cd audio-guided-fmri-video-reconstruction
# !pip install -r requirements.txt

# %%
import pandas as pd
from src.video.qualitative import launch_annotation_ui

CSV_PATH = "/content/drive/MyDrive/Research/evaluation/qualitative/qualitative_summary_notes.csv"

df = pd.read_csv(CSV_PATH)
df = df.reset_index(drop=True)

launch_annotation_ui(df, CSV_PATH)
